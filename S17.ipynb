# %%
import torch
torch.cuda.is_available()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       2 torch.cuda.is_available()
#
# File c:\Users\Viraj Bhanushali\.virtualenvs\TSAI-ERAv2-S16_17-2u8jVzRe\Lib\site-packages\torch\__init__.py:148
#     146                 err = ctypes.WinError(ctypes.get_last_error())
#     147                 err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 148                 raise err
#     150     kernel32.SetErrorMode(prev_error_mode)
#     153 def _preload_cuda_deps(lib_folder, lib_name):
#
# OSError: [WinError 126] The specified module could not be found. Error loading "c:\Users\Viraj Bhanushali\.virtualenvs\TSAI-ERAv2-S16_17-2u8jVzRe\Lib\site-packages\torch\lib\fbgemm.dll" or one of its dependencies.

# %%
# !pip install tokenizers
# !pip install torchtext
# !pip install pytorch_lightning
# !pip install datasets
# !pip install tensorboard
# Out:
# Collecting tokenizers
#   Downloading tokenizers-0.20.0-cp312-none-win_amd64.whl.metadata (6.9 kB)
# Collecting huggingface-hub<1.0,>=0.16.4 (from tokenizers)
#   Downloading huggingface_hub-0.24.5-py3-none-any.whl.metadata (13 kB)
# Collecting filelock (from huggingface-hub<1.0,>=0.16.4->tokenizers)
#   Using cached filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.16.4->tokenizers)
#   Using cached fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=20.9 in c:\users\viraj bhanushali\appdata\roaming\python\python312\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (24.1)
# Collecting pyyaml>=5.1 (from huggingface-hub<1.0,>=0.16.4->tokenizers)
#   Downloading PyYAML-6.0.2-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Collecting requests (from huggingface-hub<1.0,>=0.16.4->tokenizers)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tqdm>=4.42.1 (from huggingface-hub<1.0,>=0.16.4->tokenizers)
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (4.12.2)
# Requirement already satisfied: colorama in c:\users\viraj bhanushali\appdata\roaming\python\python312\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0,>=0.16.4->tokenizers) (0.4.6)
# Collecting charset-normalizer<4,>=2 (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers)
#   Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# Collecting idna<4,>=2.5 (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers)
#   Downloading urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers)
#   Using cached certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# Downloading tokenizers-0.20.0-cp312-none-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 10.9 MB/s eta 0:00:00
# Downloading huggingface_hub-0.24.5-py3-none-any.whl (417 kB)
# Using cached fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Downloading PyYAML-6.0.2-cp312-cp312-win_amd64.whl (156 kB)
# Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Using cached filelock-3.15.4-py3-none-any.whl (16 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached certifi-2024.7.4-py3-none-any.whl (162 kB)
# Downloading charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl (100 kB)
# Downloading idna-3.7-py3-none-any.whl (66 kB)
# Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
# Installing collected packages: urllib3, tqdm, pyyaml, idna, fsspec, filelock, charset-normalizer, certifi, requests, huggingface-hub, tokenizers
# Successfully installed certifi-2024.7.4 charset-normalizer-3.3.2 filelock-3.15.4 fsspec-2024.6.1 huggingface-hub-0.24.5 idna-3.7 pyyaml-6.0.2 requests-2.32.3 tokenizers-0.20.0 tqdm-4.66.5 urllib3-2.2.2
# Collecting torchtext
#   Downloading torchtext-0.18.0-cp312-cp312-win_amd64.whl.metadata (7.9 kB)
# Requirement already satisfied: tqdm in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from torchtext) (4.66.5)
# Requirement already satisfied: requests in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from torchtext) (2.32.3)
# Collecting torch>=2.3.0 (from torchtext)
#   Using cached torch-2.4.0-cp312-cp312-win_amd64.whl.metadata (27 kB)
# Collecting numpy (from torchtext)
#   Downloading numpy-2.0.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: filelock in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from torch>=2.3.0->torchtext) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from torch>=2.3.0->torchtext) (4.12.2)
# Collecting sympy (from torch>=2.3.0->torchtext)
#   Using cached sympy-1.13.2-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=2.3.0->torchtext)
#   Using cached networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting jinja2 (from torch>=2.3.0->torchtext)
#   Using cached jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: fsspec in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from torch>=2.3.0->torchtext) (2024.6.1)
# Requirement already satisfied: setuptools in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from torch>=2.3.0->torchtext) (72.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from requests->torchtext) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from requests->torchtext) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from requests->torchtext) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from requests->torchtext) (2024.7.4)
# Requirement already satisfied: colorama in c:\users\viraj bhanushali\appdata\roaming\python\python312\site-packages (from tqdm->torchtext) (0.4.6)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=2.3.0->torchtext)
#   Using cached MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch>=2.3.0->torchtext)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading torchtext-0.18.0-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 12.0 MB/s eta 0:00:00
# Using cached torch-2.4.0-cp312-cp312-win_amd64.whl (197.8 MB)
# Downloading numpy-2.0.1-cp312-cp312-win_amd64.whl (16.3 MB)
#    ---------------------------------------- 0.0/16.3 MB ? eta -:--:--
#    ------- -------------------------------- 3.1/16.3 MB 15.4 MB/s eta 0:00:01
#    -------------- ------------------------- 6.0/16.3 MB 14.8 MB/s eta 0:00:01
#    --------------------- ------------------ 8.9/16.3 MB 14.6 MB/s eta 0:00:01
#    ------------------------- -------------- 10.2/16.3 MB 12.5 MB/s eta 0:00:01
#    --------------------------- ------------ 11.3/16.3 MB 11.4 MB/s eta 0:00:01
#    ------------------------------ --------- 12.3/16.3 MB 10.3 MB/s eta 0:00:01
#    -------------------------------- ------- 13.1/16.3 MB 9.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 14.2/16.3 MB 8.7 MB/s eta 0:00:01
#    ------------------------------------- -- 15.2/16.3 MB 8.2 MB/s eta 0:00:01
#    -------------------------------------- - 15.7/16.3 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------- 16.3/16.3 MB 7.5 MB/s eta 0:00:00
# Using cached jinja2-3.1.4-py3-none-any.whl (133 kB)
# Using cached networkx-3.3-py3-none-any.whl (1.7 MB)
# Using cached sympy-1.13.2-py3-none-any.whl (6.2 MB)
# Using cached MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl (17 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, sympy, numpy, networkx, MarkupSafe, jinja2, torch, torchtext
# Successfully installed MarkupSafe-2.1.5 jinja2-3.1.4 mpmath-1.3.0 networkx-3.3 numpy-2.0.1 sympy-1.13.2 torch-2.4.0 torchtext-0.18.0
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: torch>=2.1.0 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from pytorch_lightning) (2.4.0)
# Requirement already satisfied: tqdm>=4.57.0 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from pytorch_lightning) (4.66.5)
# Requirement already satisfied: PyYAML>=5.4 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from pytorch_lightning) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2024.6.1)
# Collecting torchmetrics>=0.7.0 (from pytorch_lightning)
#   Downloading torchmetrics-1.4.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\viraj bhanushali\appdata\roaming\python\python312\site-packages (from pytorch_lightning) (24.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from pytorch_lightning) (4.12.2)
# Collecting lightning-utilities>=0.10.0 (from pytorch_lightning)
#   Downloading lightning_utilities-0.11.6-py3-none-any.whl.metadata (5.2 kB)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading aiohttp-3.10.3-cp312-cp312-win_amd64.whl.metadata (7.8 kB)
# Requirement already satisfied: setuptools in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from lightning-utilities>=0.10.0->pytorch_lightning) (72.1.0)
# Requirement already satisfied: filelock in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from torch>=2.1.0->pytorch_lightning) (3.15.4)
# Requirement already satisfied: sympy in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from torch>=2.1.0->pytorch_lightning) (1.13.2)
# Requirement already satisfied: networkx in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from torch>=2.1.0->pytorch_lightning) (3.3)
# Requirement already satisfied: jinja2 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from torch>=2.1.0->pytorch_lightning) (3.1.4)
# Requirement already satisfied: numpy>1.20.0 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from torchmetrics>=0.7.0->pytorch_lightning) (2.0.1)
# Requirement already satisfied: colorama in c:\users\viraj bhanushali\appdata\roaming\python\python312\site-packages (from tqdm>=4.57.0->pytorch_lightning) (0.4.6)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading aiohappyeyeballs-2.3.6-py3-none-any.whl.metadata (5.8 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs>=17.3.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading frozenlist-1.4.1-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading multidict-6.0.5-cp312-cp312-win_amd64.whl.metadata (4.3 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading yarl-1.9.4-cp312-cp312-win_amd64.whl.metadata (32 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from jinja2->torch>=2.1.0->pytorch_lightning) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from sympy->torch>=2.1.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: idna>=2.0 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from yarl<2.0,>=1.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch_lightning) (3.7)
# Downloading pytorch_lightning-2.4.0-py3-none-any.whl (815 kB)
#    ---------------------------------------- 0.0/815.2 kB ? eta -:--:--
#    --------------------------------------- 815.2/815.2 kB 17.8 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.6-py3-none-any.whl (26 kB)
# Downloading torchmetrics-1.4.1-py3-none-any.whl (866 kB)
#    ---------------------------------------- 0.0/866.2 kB ? eta -:--:--
#    --------------------------------------- 866.2/866.2 kB 12.9 MB/s eta 0:00:00
# Downloading aiohttp-3.10.3-cp312-cp312-win_amd64.whl (377 kB)
# Downloading aiohappyeyeballs-2.3.6-py3-none-any.whl (12 kB)
# Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
# Downloading frozenlist-1.4.1-cp312-cp312-win_amd64.whl (50 kB)
# Downloading multidict-6.0.5-cp312-cp312-win_amd64.whl (27 kB)
# Downloading yarl-1.9.4-cp312-cp312-win_amd64.whl (76 kB)
# Installing collected packages: multidict, lightning-utilities, frozenlist, attrs, aiohappyeyeballs, yarl, aiosignal, torchmetrics, aiohttp, pytorch_lightning
# Successfully installed aiohappyeyeballs-2.3.6 aiohttp-3.10.3 aiosignal-1.3.1 attrs-24.2.0 frozenlist-1.4.1 lightning-utilities-0.11.6 multidict-6.0.5 pytorch_lightning-2.4.0 torchmetrics-1.4.1 yarl-1.9.4
# Collecting datasets
#   Downloading datasets-2.21.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: filelock in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from datasets) (3.15.4)
# Requirement already satisfied: numpy>=1.17 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from datasets) (2.0.1)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-17.0.0-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets)
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: requests>=2.32.2 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from datasets) (4.66.5)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp312-cp312-win_amd64.whl.metadata (12 kB)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from datasets) (3.10.3)
# Requirement already satisfied: huggingface-hub>=0.21.2 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from datasets) (0.24.5)
# Requirement already satisfied: packaging in c:\users\viraj bhanushali\appdata\roaming\python\python312\site-packages (from datasets) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from aiohttp->datasets) (2.3.6)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from requests>=2.32.2->datasets) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from requests>=2.32.2->datasets) (2024.7.4)
# Requirement already satisfied: colorama in c:\users\viraj bhanushali\appdata\roaming\python\python312\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\viraj bhanushali\appdata\roaming\python\python312\site-packages (from pandas->datasets) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->datasets)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->datasets)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\viraj bhanushali\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-2.21.0-py3-none-any.whl (527 kB)
#    ---------------------------------------- 0.0/527.3 kB ? eta -:--:--
#    ---------------------------------------- 527.3/527.3 kB 8.6 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading pyarrow-17.0.0-cp312-cp312-win_amd64.whl (25.1 MB)
#    ---------------------------------------- 0.0/25.1 MB ? eta -:--:--
#    ---- ----------------------------------- 2.6/25.1 MB 12.6 MB/s eta 0:00:02
#    --------- ------------------------------ 5.8/25.1 MB 13.6 MB/s eta 0:00:02
#    -------------- ------------------------- 8.9/25.1 MB 14.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 10.2/25.1 MB 13.0 MB/s eta 0:00:02
#    ------------------ --------------------- 11.5/25.1 MB 11.5 MB/s eta 0:00:02
#    -------------------- ------------------- 12.8/25.1 MB 10.3 MB/s eta 0:00:02
#    ---------------------- ----------------- 13.9/25.1 MB 9.9 MB/s eta 0:00:02
#    ------------------------ --------------- 15.2/25.1 MB 9.4 MB/s eta 0:00:02
#    ------------------------- -------------- 16.0/25.1 MB 8.8 MB/s eta 0:00:02
#    --------------------------- ------------ 17.0/25.1 MB 8.4 MB/s eta 0:00:01
#    ----------------------------- ---------- 18.4/25.1 MB 8.2 MB/s eta 0:00:01
#    ------------------------------- -------- 19.7/25.1 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 21.5/25.1 MB 8.0 MB/s eta 0:00:01
#    ------------------------------------ --- 23.1/25.1 MB 8.0 MB/s eta 0:00:01
#    -------------------------------------- - 24.1/25.1 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------- 25.1/25.1 MB 7.6 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
# Downloading xxhash-3.4.1-cp312-cp312-win_amd64.whl (29 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Installing collected packages: pytz, xxhash, tzdata, pyarrow, dill, pandas, multiprocess, datasets
# Successfully installed datasets-2.21.0 dill-0.3.8 multiprocess-0.70.16 pandas-2.2.2 pyarrow-17.0.0 pytz-2024.1 tzdata-2024.1 xxhash-3.4.1
# Collecting tensorboard
#   Downloading tensorboard-2.17.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting absl-py>=0.4 (from tensorboard)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard)
#   Downloading grpcio-1.65.4-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Collecting markdown>=2.6.8 (from tensorboard)
#   Downloading Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: numpy>=1.12.0 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from tensorboard) (2.0.1)
# Requirement already satisfied: packaging in c:\users\viraj bhanushali\appdata\roaming\python\python312\site-packages (from tensorboard) (24.1)
# Collecting protobuf!=4.24.0,>=3.19.6 (from tensorboard)
#   Downloading protobuf-5.27.3-cp310-abi3-win_amd64.whl.metadata (592 bytes)
# Requirement already satisfied: setuptools>=41.0.0 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from tensorboard) (72.1.0)
# Requirement already satisfied: six>1.9 in c:\users\viraj bhanushali\appdata\roaming\python\python312\site-packages (from tensorboard) (1.16.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard)
#   Downloading werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\coding\tsai-erav2-s16_17\.conda\lib\site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)
# Downloading tensorboard-2.17.1-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    --------- ------------------------------ 1.3/5.5 MB 13.4 MB/s eta 0:00:01
#    ------------- -------------------------- 1.8/5.5 MB 4.6 MB/s eta 0:00:01
#    ------------------- -------------------- 2.6/5.5 MB 4.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.1/5.5 MB 3.9 MB/s eta 0:00:01
#    -------------------------- ------------- 3.7/5.5 MB 3.8 MB/s eta 0:00:01
#    -------------------------------- ------- 4.5/5.5 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 3.8 MB/s eta 0:00:00
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading grpcio-1.65.4-cp312-cp312-win_amd64.whl (4.1 MB)
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ------------ --------------------------- 1.3/4.1 MB 6.7 MB/s eta 0:00:01
#    --------------------------- ------------ 2.9/4.1 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 4.1/4.1 MB 8.0 MB/s eta 0:00:00
# Downloading Markdown-3.6-py3-none-any.whl (105 kB)
# Downloading protobuf-5.27.3-cp310-abi3-win_amd64.whl (426 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading werkzeug-3.0.3-py3-none-any.whl (227 kB)
# Installing collected packages: werkzeug, tensorboard-data-server, protobuf, markdown, grpcio, absl-py, tensorboard
# Successfully installed absl-py-2.1.0 grpcio-1.65.4 markdown-3.6 protobuf-5.27.3 tensorboard-2.17.1 tensorboard-data-server-0.7.2 werkzeug-3.0.3

# %%
from config_file import get_config
from train import train_model

config = get_config()
config["batch_size"] = 16
config["preload"] = None
config["num_epochs"] = 15
# Out:
# d:\Coding\TSAI-ERAv2-S16_17\.conda\Lib\site-packages\torchtext\datasets\__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# d:\Coding\TSAI-ERAv2-S16_17\.conda\Lib\site-packages\torchtext\data\__init__.py:4: UserWarning:
# /!\ IMPORTANT WARNING ABOUT TORCHTEXT STATUS /!\
# Torchtext is deprecated and the last released version will be 0.18 (this one). You can silence this warning by calling the following at the beginnign of your scripts: `import torchtext; torchtext.disable_torchtext_deprecation_warning()`
#   warnings.warn(torchtext._TORCHTEXT_DEPRECATION_MSG)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: DLL load failed while importing _multiarray_umath: The specified module could not be found.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 from config_file import get_config
# ----> 2 from train import train_model
#       4 config = get_config()
#       5 config["batch_size"] = 16
#
# File d:\Coding\TSAI-ERAv2-S16_17\train.py:18
#      15 import os
#      16 from pathlib import Path
# ---> 18 from datasets import load_dataset
#      19 from tokenizers import Tokenizer
#      20 from tokenizers.models import WordLevel
#
# File d:\Coding\TSAI-ERAv2-S16_17\.conda\Lib\site-packages\datasets\__init__.py:17
#       1 # Copyright 2020 The HuggingFace Datasets Authors and the TensorFlow Datasets Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 __version__ = "2.21.0"
# ---> 17 from .arrow_dataset import Dataset
#      18 from .arrow_reader import ReadInstruction
#      19 from .builder import ArrowBasedBuilder, BeamBasedBuilder, BuilderConfig, DatasetBuilder, GeneratorBasedBuilder
#
# File d:\Coding\TSAI-ERAv2-S16_17\.conda\Lib\site-packages\datasets\arrow_dataset.py:59
#      57 import fsspec
#      58 import numpy as np
# ---> 59 import pandas as pd
#      60 import pyarrow as pa
#      61 import pyarrow.compute as pc
#
# File d:\Coding\TSAI-ERAv2-S16_17\.conda\Lib\site-packages\pandas\__init__.py:62
#      59 # let init-time option registration happen
#      60 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
# ---> 62 from pandas.core.api import (
#      63     # dtype
#      64     ArrowDtype,
#      65     Int8Dtype,
#      66     Int16Dtype,
#      67     Int32Dtype,
#      68     Int64Dtype,
#      69     UInt8Dtype,
#      70     UInt16Dtype,
#      71     UInt32Dtype,
#      72     UInt64Dtype,
#      73     Float32Dtype,
#      74     Float64Dtype,
#      75     CategoricalDtype,
#      76     PeriodDtype,
#      77     IntervalDtype,
#      78     DatetimeTZDtype,
#      79     StringDtype,
#      80     BooleanDtype,
#      81     # missing
#      82     NA,
#      83     isna,
#      84     isnull,
#      85     notna,
#      86     notnull,
#      87     # indexes
#      88     Index,
#      89     CategoricalIndex,
#      90     RangeIndex,
#      91     MultiIndex,
#      92     IntervalIndex,
#      93     TimedeltaIndex,
#      94     DatetimeIndex,
#      95     PeriodIndex,
#      96     IndexSlice,
#      97     # tseries
#      98     NaT,
#      99     Period,
#     100     period_range,
#     101     Timedelta,
#     102     timedelta_range,
#     103     Timestamp,
#     104     date_range,
#     105     bdate_range,
#     106     Interval,
#     107     interval_range,
#     108     DateOffset,
#     109     # conversion
#     110     to_numeric,
#     111     to_datetime,
#     112     to_timedelta,
#     113     # misc
#     114     Flags,
#     115     Grouper,
#     116     factorize,
#     117     unique,
#     118     value_counts,
#     119     NamedAgg,
#     120     array,
#     121     Categorical,
#     122     set_eng_float_format,
#     123     Series,
#     124     DataFrame,
#     125 )
#     127 from pandas.core.dtypes.dtypes import SparseDtype
#     129 from pandas.tseries.api import infer_freq
#
# File d:\Coding\TSAI-ERAv2-S16_17\.conda\Lib\site-packages\pandas\core\api.py:1
# ----> 1 from pandas._libs import (
#       2     NaT,
#       3     Period,
#       4     Timedelta,
#       5     Timestamp,
#       6 )
#       7 from pandas._libs.missing import NA
#       9 from pandas.core.dtypes.dtypes import (
#      10     ArrowDtype,
#      11     CategoricalDtype,
#    (...)
#      14     PeriodDtype,
#      15 )
#
# File d:\Coding\TSAI-ERAv2-S16_17\.conda\Lib\site-packages\pandas\_libs\__init__.py:17
#      13 # Below imports needs to happen first to ensure pandas top level
#      14 # module gets monkeypatched with the pandas_datetime_CAPI
#      15 # see pandas_datetime_exec in pd_datetime.c
#      16 import pandas._libs.pandas_parser  # isort: skip # type: ignore[reportUnusedImport]
# ---> 17 import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
#      18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#      21     NaTType,
#    (...)
#      26     iNaT,
#      27 )
#
# ImportError: numpy._core.multiarray failed to import

# %%
train_model(config)
